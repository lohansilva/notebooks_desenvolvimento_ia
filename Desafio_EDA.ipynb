# %% [markdown]
# <a href="https://colab.research.google.com/github/lohansilva/notebooks_desenvolvimento_ia/blob/main/Desafio_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Notebooks/datasets/netflix daily top 10.csv')

# %%
df.head(3)
# Out:
#         As of  Rank Year to Date Rank Last Week Rank  \
# 0  2020-04-01     1                 1              1
# 1  2020-04-01     2                 2              -
# 2  2020-04-01     3                 3              2
#
#                           Title     Type Netflix Exclusive  \
# 0  Tiger King: Murder, Mayhem …  TV Show               Yes
# 1                         Ozark  TV Show               Yes
# 2                  All American  TV Show               NaN
#
#   Netflix Release Date  Days In Top 10  Viewership Score
# 0         Mar 20, 2020               9                90
# 1         Jul 21, 2017               5                45
# 2         Mar 28, 2019               9                76

# %%
#TODO:Tipos de dados disponíveis
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7100 entries, 0 to 7099
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   As of                 7100 non-null   object
#  1   Rank                  7100 non-null   int64
#  2   Year to Date Rank     7100 non-null   object
#  3   Last Week Rank        7100 non-null   object
#  4   Title                 7100 non-null   object
#  5   Type                  7100 non-null   object
#  6   Netflix Exclusive     4599 non-null   object
#  7   Netflix Release Date  7100 non-null   object
#  8   Days In Top 10        7100 non-null   int64
#  9   Viewership Score      7100 non-null   int64
# dtypes: int64(3), object(7)
# memory usage: 554.8+ KB

# %%
#TODO:Período da análise feita
df['As of'].min()
# Out:
# '2020-04-01'

# %%
#TODO:Período da análise feita
df['As of'].max()
# Out:
# '2022-03-11'

# %%
#TODO:Tamanho da base de dados
df.shape
# Out:
# (7100, 10)

# %%
#TODO:Verificar dados nulos
df.isnull().sum()
# Out:
# As of                      0
# Rank                       0
# Year to Date Rank          0
# Last Week Rank             0
# Title                      0
# Type                       0
# Netflix Exclusive       2501
# Netflix Release Date       0
# Days In Top 10             0
# Viewership Score           0
# dtype: int64

# %%
#TODO:Outliers
df.describe()
# Out:
#               Rank  Days In Top 10  Viewership Score
# count  7100.000000     7100.000000       7100.000000
# mean      5.500000       24.123662        122.790141
# std       2.872484       58.473789        213.861642
# min       1.000000        1.000000          1.000000
# 25%       3.000000        3.000000         19.000000
# 50%       5.500000        7.000000         50.000000
# 75%       8.000000       18.000000        128.000000
# max      10.000000      428.000000       1474.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Rank'].plot(kind='hist', bins=20, title='Rank')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Days In Top 10'].plot(kind='hist', bins=20, title='Days In Top 10')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
df.plot(kind='box',figsize=(10,6),subplots=True);
